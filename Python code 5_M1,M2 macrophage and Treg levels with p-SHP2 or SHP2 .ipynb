# %%
import pandas as pd
import numpy as np

# %%
# import the RPPA dataset
# clean the RPPA dataset by listing p-SHP2 levels of patients
rppa = pd.read_csv("RPPA2.csv")
rppa = rppa.transpose()
rppa = rppa.drop("Unnamed: 0")
rppa.columns=rppa.iloc[0]
rppa = rppa.drop("Composite.Element.REF")
rppa.index = [x.lower() for x in rppa.index]
rppa.index.rename("cell_type", inplace=True)
sub=rppa[["PTPN11|SHP-2_pY542","FN1|Fibronectin"]]
sub
# Out:
# Composite.Element.REF       PTPN11|SHP-2_pY542 FN1|Fibronectin
# cell_type
# tcga.3c.aali.01a.21.a43f.20          -0.521618        1.937218
# tcga.3c.aalk.01a.21.a43f.20          -0.526931        0.242808
# tcga.4h.aaak.01a.21.a43f.20          -0.370444        1.726744
# tcga.5l.aat1.01a.21.a43f.20          -0.328153       -0.166293
# tcga.5t.a9qa.01a.21.a43f.20          -0.701329       -0.906289
# ...                                        ...             ...
# tcga.wt.ab41.01a.21.a43f.20          -0.177261       -0.052281
# tcga.xx.a899.11a.51.a43o.20          -0.128184         0.53226
# tcga.xx.a899.01a.21.a43f.20           -0.07137       -0.379777
# tcga.z7.a8r5.01a.51.a43f.20          -0.105476       -0.607824
# tcga.z7.a8r6.01a.21.a43f.20           -0.07874        0.146895
#
# [937 rows x 2 columns]

# %%
# import the quantiseq results from the R code 1.
quanti = pd.read_csv("result_quantiseq.csv", index_col="cell_type").drop("Unnamed: 0",1).transpose()
quanti
# Out:
# C:\Users\hchen\AppData\Local\Temp/ipykernel_30060/1526547612.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   quanti = pd.read_csv("result_quantiseq.csv", index_col="cell_type").drop("Unnamed: 0",1).transpose()
# cell_type                      B cell  Macrophage M1  Macrophage M2  Monocyte  \
# tcga.bh.a0ea.01a.21.a13c.20  0.202937       0.205333       0.012593       0.0
# tcga.bh.a18h.01a.21.a13f.20  0.237603       0.687610       0.000000       0.0
# tcga.c8.a1hl.01a.21.a17j.20  0.054733       0.383638       0.000000       0.0
# tcga.d8.a146.01a.21.a13d.20  0.258713       0.189064       0.010984       0.0
# tcga.e2.a158.01a.21.a13e.20  0.132438       0.135486       0.000000       0.0
# ...                               ...            ...            ...       ...
# tcga.e2.a1b1.01a.11.a13e.20  0.196758       0.375158       0.009153       0.0
# tcga.e2.a1b4.01a.21.a13e.20  0.096378       0.134270       0.176374       0.0
# tcga.e2.a1b5.01a.31.a13e.20  0.822114       0.058037       0.000000       0.0
# tcga.e2.a1b6.01a.21.a13e.20  0.608823       0.284792       0.000000       0.0
# tcga.e2.a1bd.01a.21.a13e.20  0.100182       0.101965       0.086560       0.0
#
# cell_type                    Neutrophil   NK cell  \
# tcga.bh.a0ea.01a.21.a13c.20    0.432566  0.125718
# tcga.bh.a18h.01a.21.a13f.20    0.000000  0.074787
# tcga.c8.a1hl.01a.21.a17j.20    0.518007  0.043622
# tcga.d8.a146.01a.21.a13d.20    0.430990  0.103141
# tcga.e2.a158.01a.21.a13e.20    0.355945  0.127391
# ...                                 ...       ...
# tcga.e2.a1b1.01a.11.a13e.20    0.181040  0.174135
# tcga.e2.a1b4.01a.21.a13e.20    0.256750  0.094679
# tcga.e2.a1b5.01a.31.a13e.20    0.000000  0.119848
# tcga.e2.a1b6.01a.21.a13e.20    0.000000  0.106385
# tcga.e2.a1bd.01a.21.a13e.20    0.196877  0.087766
#
# cell_type                    T cell CD4+ (non-regulatory)  T cell CD8+  \
# tcga.bh.a0ea.01a.21.a13c.20                           0.0          0.0
# tcga.bh.a18h.01a.21.a13f.20                           0.0          0.0
# tcga.c8.a1hl.01a.21.a17j.20                           0.0          0.0
# tcga.d8.a146.01a.21.a13d.20                           0.0          0.0
# tcga.e2.a158.01a.21.a13e.20                           0.0          0.0
# ...                                                   ...          ...
# tcga.e2.a1b1.01a.11.a13e.20                           0.0          0.0
# tcga.e2.a1b4.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1b5.01a.31.a13e.20                           0.0          0.0
# tcga.e2.a1b6.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1bd.01a.21.a13e.20                           0.0          0.0
#
# cell_type                    T cell regulatory (Tregs)  \
# tcga.bh.a0ea.01a.21.a13c.20                   0.020854
# tcga.bh.a18h.01a.21.a13f.20                   0.000000
# tcga.c8.a1hl.01a.21.a17j.20                   0.000000
# tcga.d8.a146.01a.21.a13d.20                   0.007108
# tcga.e2.a158.01a.21.a13e.20                   0.104112
# ...                                                ...
# tcga.e2.a1b1.01a.11.a13e.20                   0.063757
# tcga.e2.a1b4.01a.21.a13e.20                   0.188536
# tcga.e2.a1b5.01a.31.a13e.20                   0.000000
# tcga.e2.a1b6.01a.21.a13e.20                   0.000000
# tcga.e2.a1bd.01a.21.a13e.20                   0.146707
#
# cell_type                    Myeloid dendritic cell  uncharacterized cell
# tcga.bh.a0ea.01a.21.a13c.20                0.000000          1.110223e-16
# tcga.bh.a18h.01a.21.a13f.20                0.000000          2.220446e-16
# tcga.c8.a1hl.01a.21.a17j.20                0.000000          0.000000e+00
# tcga.d8.a146.01a.21.a13d.20                0.000000          2.220446e-16
# tcga.e2.a158.01a.21.a13e.20                0.056090          8.853759e-02
# ...                                             ...                   ...
# tcga.e2.a1b1.01a.11.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1b4.01a.21.a13e.20                0.023231          2.978108e-02
# tcga.e2.a1b5.01a.31.a13e.20                0.000000          4.440892e-16
# tcga.e2.a1b6.01a.21.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1bd.01a.21.a13e.20                0.063306          2.166371e-01
#
# [207 rows x 11 columns]

# %%
#merge the quantiseq results with RPPA dataset
res=quanti.merge(sub,how='inner',left_index=True, right_index=True).astype(float)
res
# Out:
#                                B cell  Macrophage M1  Macrophage M2  Monocyte  \
# tcga.bh.a0ea.01a.21.a13c.20  0.202937       0.205333       0.012593       0.0
# tcga.bh.a18h.01a.21.a13f.20  0.237603       0.687610       0.000000       0.0
# tcga.c8.a1hl.01a.21.a17j.20  0.054733       0.383638       0.000000       0.0
# tcga.d8.a146.01a.21.a13d.20  0.258713       0.189064       0.010984       0.0
# tcga.e2.a158.01a.21.a13e.20  0.132438       0.135486       0.000000       0.0
# ...                               ...            ...            ...       ...
# tcga.e2.a1b1.01a.11.a13e.20  0.196758       0.375158       0.009153       0.0
# tcga.e2.a1b4.01a.21.a13e.20  0.096378       0.134270       0.176374       0.0
# tcga.e2.a1b5.01a.31.a13e.20  0.822114       0.058037       0.000000       0.0
# tcga.e2.a1b6.01a.21.a13e.20  0.608823       0.284792       0.000000       0.0
# tcga.e2.a1bd.01a.21.a13e.20  0.100182       0.101965       0.086560       0.0
#
#                              Neutrophil   NK cell  \
# tcga.bh.a0ea.01a.21.a13c.20    0.432566  0.125718
# tcga.bh.a18h.01a.21.a13f.20    0.000000  0.074787
# tcga.c8.a1hl.01a.21.a17j.20    0.518007  0.043622
# tcga.d8.a146.01a.21.a13d.20    0.430990  0.103141
# tcga.e2.a158.01a.21.a13e.20    0.355945  0.127391
# ...                                 ...       ...
# tcga.e2.a1b1.01a.11.a13e.20    0.181040  0.174135
# tcga.e2.a1b4.01a.21.a13e.20    0.256750  0.094679
# tcga.e2.a1b5.01a.31.a13e.20    0.000000  0.119848
# tcga.e2.a1b6.01a.21.a13e.20    0.000000  0.106385
# tcga.e2.a1bd.01a.21.a13e.20    0.196877  0.087766
#
#                              T cell CD4+ (non-regulatory)  T cell CD8+  \
# tcga.bh.a0ea.01a.21.a13c.20                           0.0          0.0
# tcga.bh.a18h.01a.21.a13f.20                           0.0          0.0
# tcga.c8.a1hl.01a.21.a17j.20                           0.0          0.0
# tcga.d8.a146.01a.21.a13d.20                           0.0          0.0
# tcga.e2.a158.01a.21.a13e.20                           0.0          0.0
# ...                                                   ...          ...
# tcga.e2.a1b1.01a.11.a13e.20                           0.0          0.0
# tcga.e2.a1b4.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1b5.01a.31.a13e.20                           0.0          0.0
# tcga.e2.a1b6.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1bd.01a.21.a13e.20                           0.0          0.0
#
#                              T cell regulatory (Tregs)  \
# tcga.bh.a0ea.01a.21.a13c.20                   0.020854
# tcga.bh.a18h.01a.21.a13f.20                   0.000000
# tcga.c8.a1hl.01a.21.a17j.20                   0.000000
# tcga.d8.a146.01a.21.a13d.20                   0.007108
# tcga.e2.a158.01a.21.a13e.20                   0.104112
# ...                                                ...
# tcga.e2.a1b1.01a.11.a13e.20                   0.063757
# tcga.e2.a1b4.01a.21.a13e.20                   0.188536
# tcga.e2.a1b5.01a.31.a13e.20                   0.000000
# tcga.e2.a1b6.01a.21.a13e.20                   0.000000
# tcga.e2.a1bd.01a.21.a13e.20                   0.146707
#
#                              Myeloid dendritic cell  uncharacterized cell  \
# tcga.bh.a0ea.01a.21.a13c.20                0.000000          1.110223e-16
# tcga.bh.a18h.01a.21.a13f.20                0.000000          2.220446e-16
# tcga.c8.a1hl.01a.21.a17j.20                0.000000          0.000000e+00
# tcga.d8.a146.01a.21.a13d.20                0.000000          2.220446e-16
# tcga.e2.a158.01a.21.a13e.20                0.056090          8.853759e-02
# ...                                             ...                   ...
# tcga.e2.a1b1.01a.11.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1b4.01a.21.a13e.20                0.023231          2.978108e-02
# tcga.e2.a1b5.01a.31.a13e.20                0.000000          4.440892e-16
# tcga.e2.a1b6.01a.21.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1bd.01a.21.a13e.20                0.063306          2.166371e-01
#
#                              PTPN11|SHP-2_pY542  FN1|Fibronectin
# tcga.bh.a0ea.01a.21.a13c.20            0.171237         1.022859
# tcga.bh.a18h.01a.21.a13f.20           -0.130730        -0.451199
# tcga.c8.a1hl.01a.21.a17j.20           -0.329654        -0.602501
# tcga.d8.a146.01a.21.a13d.20            0.084902         0.101375
# tcga.e2.a158.01a.21.a13e.20            0.401267        -1.358473
# ...                                         ...              ...
# tcga.e2.a1b1.01a.11.a13e.20           -0.040056         0.758293
# tcga.e2.a1b4.01a.21.a13e.20           -0.131655         0.278222
# tcga.e2.a1b5.01a.31.a13e.20           -0.323479        -1.733666
# tcga.e2.a1b6.01a.21.a13e.20           -0.322786        -1.298980
# tcga.e2.a1bd.01a.21.a13e.20           -0.183289        -0.358511
#
# [207 rows x 13 columns]

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential p-SHP2 patient groups. 
div = np.median(res["Macrophage M1"])
res2_high = res.where(res["Macrophage M1"]>=div).dropna()
res2_low = res.where(res["Macrophage M1"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11|SHP-2_pY542"],res2_high["PTPN11|SHP-2_pY542"]]
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('blue')
    pc.set_alpha(0.5)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11|SHP-2_pY542"]),np.median(res2_low["PTPN11|SHP-2_pY542"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('*, p=0.0276',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n M1 Macrophage Scores',"Patients with higher \n M1 Macrophage Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("p-SHP2 (Y542) Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11|SHP-2_pY542"])-np.mean(res2_low["PTPN11|SHP-2_pY542"])
gap
# Out:
# -0.09149649509083271

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential p-SHP2 patient groups. 
div = np.median(res["Macrophage M2"])
res2_high = res.where(res["Macrophage M2"]>=div).dropna()
res2_low = res.where(res["Macrophage M2"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11|SHP-2_pY542"],res2_high["PTPN11|SHP-2_pY542"]]
data_to_plot
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('red')
    pc.set_alpha(0.2)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11|SHP-2_pY542"]),np.median(res2_low["PTPN11|SHP-2_pY542"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('NS, p=0.319',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n M2 Macrophage Scores',"Patients with higher \n M2 Macrophage Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("p-SHP2 (Y542) Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11|SHP-2_pY542"])-np.mean(res2_low["PTPN11|SHP-2_pY542"])
gap
# Out:
# 0.01813128384055264

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential p-SHP2 patient groups. 
div = np.median(res["T cell regulatory (Tregs)"])
res2_high = res.where(res["T cell regulatory (Tregs)"]>=div).dropna()
res2_low = res.where(res["T cell regulatory (Tregs)"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11|SHP-2_pY542"],res2_high["PTPN11|SHP-2_pY542"]]
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('grey')
    pc.set_alpha(0.5)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11|SHP-2_pY542"]),np.median(res2_low["PTPN11|SHP-2_pY542"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('NS, p=0.955',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n Tregs Scores',"Patients with higher \n Tregs Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("p-SHP2 (Y542) Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11|SHP-2_pY542"])-np.mean(res2_low["PTPN11|SHP-2_pY542"])
gap
# Out:
# -0.031176064409447323

# %%
# import the mRNA dataset
mRNA=pd.read_csv("mRNA_PRRA_merged.csv")
mRNA["index"]=[x.replace("-",".") for x in mRNA["Composite.Element.REF"]]
mRNA=mRNA.set_index("index")
mRNA_sub=mRNA[["PTPN11","PTPN1"]]
mRNA_sub
# Out:
#                                PTPN11    PTPN1
# index
# tcga.bh.a0ea.01a.21.a13c.20  0.225429  0.09950
# tcga.bh.a18h.01a.21.a13f.20 -0.083571  0.84250
# tcga.c8.a1hl.01a.21.a17j.20 -1.137500 -1.16050
# tcga.d8.a146.01a.21.a13d.20 -0.280714  0.21775
# tcga.e2.a158.01a.21.a13e.20  0.422286 -0.94200
# ...                               ...      ...
# tcga.e2.a1b1.01a.11.a13e.20 -0.684071 -0.54025
# tcga.e2.a1b4.01a.21.a13e.20 -0.411714  0.26150
# tcga.e2.a1b5.01a.31.a13e.20 -0.026429  0.12600
# tcga.e2.a1b6.01a.21.a13e.20 -0.442071  0.08625
# tcga.e2.a1bd.01a.21.a13e.20 -1.509917 -0.14475
#
# [207 rows x 2 columns]

# %%
# merge the quantiseq dataset with mRNA dataset
res=quanti.merge(mRNA_sub,how='inner',left_index=True, right_index=True)
res
# Out:
#                                B cell  Macrophage M1  Macrophage M2  Monocyte  \
# tcga.bh.a0ea.01a.21.a13c.20  0.202937       0.205333       0.012593       0.0
# tcga.bh.a18h.01a.21.a13f.20  0.237603       0.687610       0.000000       0.0
# tcga.c8.a1hl.01a.21.a17j.20  0.054733       0.383638       0.000000       0.0
# tcga.d8.a146.01a.21.a13d.20  0.258713       0.189064       0.010984       0.0
# tcga.e2.a158.01a.21.a13e.20  0.132438       0.135486       0.000000       0.0
# ...                               ...            ...            ...       ...
# tcga.e2.a1b1.01a.11.a13e.20  0.196758       0.375158       0.009153       0.0
# tcga.e2.a1b4.01a.21.a13e.20  0.096378       0.134270       0.176374       0.0
# tcga.e2.a1b5.01a.31.a13e.20  0.822114       0.058037       0.000000       0.0
# tcga.e2.a1b6.01a.21.a13e.20  0.608823       0.284792       0.000000       0.0
# tcga.e2.a1bd.01a.21.a13e.20  0.100182       0.101965       0.086560       0.0
#
#                              Neutrophil   NK cell  \
# tcga.bh.a0ea.01a.21.a13c.20    0.432566  0.125718
# tcga.bh.a18h.01a.21.a13f.20    0.000000  0.074787
# tcga.c8.a1hl.01a.21.a17j.20    0.518007  0.043622
# tcga.d8.a146.01a.21.a13d.20    0.430990  0.103141
# tcga.e2.a158.01a.21.a13e.20    0.355945  0.127391
# ...                                 ...       ...
# tcga.e2.a1b1.01a.11.a13e.20    0.181040  0.174135
# tcga.e2.a1b4.01a.21.a13e.20    0.256750  0.094679
# tcga.e2.a1b5.01a.31.a13e.20    0.000000  0.119848
# tcga.e2.a1b6.01a.21.a13e.20    0.000000  0.106385
# tcga.e2.a1bd.01a.21.a13e.20    0.196877  0.087766
#
#                              T cell CD4+ (non-regulatory)  T cell CD8+  \
# tcga.bh.a0ea.01a.21.a13c.20                           0.0          0.0
# tcga.bh.a18h.01a.21.a13f.20                           0.0          0.0
# tcga.c8.a1hl.01a.21.a17j.20                           0.0          0.0
# tcga.d8.a146.01a.21.a13d.20                           0.0          0.0
# tcga.e2.a158.01a.21.a13e.20                           0.0          0.0
# ...                                                   ...          ...
# tcga.e2.a1b1.01a.11.a13e.20                           0.0          0.0
# tcga.e2.a1b4.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1b5.01a.31.a13e.20                           0.0          0.0
# tcga.e2.a1b6.01a.21.a13e.20                           0.0          0.0
# tcga.e2.a1bd.01a.21.a13e.20                           0.0          0.0
#
#                              T cell regulatory (Tregs)  \
# tcga.bh.a0ea.01a.21.a13c.20                   0.020854
# tcga.bh.a18h.01a.21.a13f.20                   0.000000
# tcga.c8.a1hl.01a.21.a17j.20                   0.000000
# tcga.d8.a146.01a.21.a13d.20                   0.007108
# tcga.e2.a158.01a.21.a13e.20                   0.104112
# ...                                                ...
# tcga.e2.a1b1.01a.11.a13e.20                   0.063757
# tcga.e2.a1b4.01a.21.a13e.20                   0.188536
# tcga.e2.a1b5.01a.31.a13e.20                   0.000000
# tcga.e2.a1b6.01a.21.a13e.20                   0.000000
# tcga.e2.a1bd.01a.21.a13e.20                   0.146707
#
#                              Myeloid dendritic cell  uncharacterized cell  \
# tcga.bh.a0ea.01a.21.a13c.20                0.000000          1.110223e-16
# tcga.bh.a18h.01a.21.a13f.20                0.000000          2.220446e-16
# tcga.c8.a1hl.01a.21.a17j.20                0.000000          0.000000e+00
# tcga.d8.a146.01a.21.a13d.20                0.000000          2.220446e-16
# tcga.e2.a158.01a.21.a13e.20                0.056090          8.853759e-02
# ...                                             ...                   ...
# tcga.e2.a1b1.01a.11.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1b4.01a.21.a13e.20                0.023231          2.978108e-02
# tcga.e2.a1b5.01a.31.a13e.20                0.000000          4.440892e-16
# tcga.e2.a1b6.01a.21.a13e.20                0.000000          2.220446e-16
# tcga.e2.a1bd.01a.21.a13e.20                0.063306          2.166371e-01
#
#                                PTPN11    PTPN1
# tcga.bh.a0ea.01a.21.a13c.20  0.225429  0.09950
# tcga.bh.a18h.01a.21.a13f.20 -0.083571  0.84250
# tcga.c8.a1hl.01a.21.a17j.20 -1.137500 -1.16050
# tcga.d8.a146.01a.21.a13d.20 -0.280714  0.21775
# tcga.e2.a158.01a.21.a13e.20  0.422286 -0.94200
# ...                               ...      ...
# tcga.e2.a1b1.01a.11.a13e.20 -0.684071 -0.54025
# tcga.e2.a1b4.01a.21.a13e.20 -0.411714  0.26150
# tcga.e2.a1b5.01a.31.a13e.20 -0.026429  0.12600
# tcga.e2.a1b6.01a.21.a13e.20 -0.442071  0.08625
# tcga.e2.a1bd.01a.21.a13e.20 -1.509917 -0.14475
#
# [207 rows x 13 columns]

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential SHP2 patient groups. 
div = np.median(res["Macrophage M1"])
res2_high = res.where(res["Macrophage M1"]>=div).dropna()
res2_low = res.where(res["Macrophage M1"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11"],res2_high["PTPN11"]]
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('blue')
    pc.set_alpha(0.5)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11"]),np.median(res2_low["PTPN11"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('NS, p=0.218',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n M1 Macrophage Scores',"Patients with higher \n M1 Macrophage Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("SHP2 Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11"])-np.mean(res2_low["PTPN11"])
gap
# Out:
# 0.062058070128827476

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential SHP2 patient groups. 
div = np.median(res["Macrophage M2"])
res2_high = res.where(res["Macrophage M2"]>=div).dropna()
res2_low = res.where(res["Macrophage M2"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11"],res2_high["PTPN11"]]
data_to_plot
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('red')
    pc.set_alpha(0.2)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11"]),np.median(res2_low["PTPN11"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('NS, p=0.111',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n M2 Macrophage Scores',"Patients with higher \n M2 Macrophage Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("SHP2 Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11"])-np.mean(res2_low["PTPN11"])
gap
# Out:
# -0.09396753141159449

# %%
import matplotlib as mpl
mpl.get_backend()
import matplotlib.pyplot as plt
# plot the viloin plot of immune scores in differential SHP2 patient groups. 
div = np.median(res["T cell regulatory (Tregs)"])
res2_high = res.where(res["T cell regulatory (Tregs)"]>=div).dropna()
res2_low = res.where(res["T cell regulatory (Tregs)"]<div).dropna()
res2_low=res2_low.astype(float)
res2_high=res2_high.astype(float)
data_to_plot=[res2_low["PTPN11"],res2_high["PTPN11"]]
plt.figure(dpi=300)
fig=plt.violinplot(data_to_plot,[1,2],showmeans=False, showextrema=False)
for pc in fig['bodies']:
    pc.set_facecolor('grey')
    pc.set_alpha(0.5)
plt.boxplot(data_to_plot, notch=True, sym="",whis=1.5)
plt.plot([1,2],[2,2],"-|", color="black")
plt.plot([0,4],[np.median(res2_low["PTPN11"]),np.median(res2_low["PTPN11"])],"--", color="black")
plt.xlim((0.5,2.5))
plt.ylim((-1.5,2.5))
plt.gca().annotate('NS, p=0.232',
            xy=(1.5, 2), xycoords='data',
            xytext=(0.36, 0.9), textcoords='axes fraction',fontsize =16)
my_xticks = ['Patients with lower \n Tregs Scores',"Patients with higher \n Tregs Scores"]
plt.xticks([1,2], my_xticks,fontsize=12)
plt.ylabel("SHP2 Level",labelpad=0.5,fontsize=16)
gap=np.mean(res2_high["PTPN11"])-np.mean(res2_low["PTPN11"])
gap
# Out:
# 0.052353343680825316
